# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(20,10))
x = np.arange(0,10)
y = np.random.random(10)
l1 = plt.subplot2grid((5,10),(0,0),colspan = 4)
l2 = plt.subplot2grid((5,10),(1,0),rowspan = 3,colspan = 2)
l3 = plt.subplot2grid((5,10),(4,0))
l4 = plt.subplot2grid((5,10),(0,4),colspan = 3)
l5 = plt.subplot2grid((5,10),(0,7),rowspan = 5)
l6 = plt.subplot2grid((5,10),(0,8),colspan = 2, rowspan =5)
l7 = plt.subplot2grid((5,10),(1,2),colspan = 5)
l8 = plt.subplot2grid((5,10),(2,2),rowspan = 2)
l9 = plt.subplot2grid((5,10),(2,3),rowspan = 2,colspan = 4)
l10 = plt.subplot2grid((5,10),(4,1),colspan = 3)
l11 = plt.subplot2grid((5,10),(4,4))
l12 = plt.subplot2grid((5,10),(4,5))
l13 = plt.subplot2grid((5,10),(4,6))
l9.bar(x,y)
plt.tight_layout()
plt.show()
